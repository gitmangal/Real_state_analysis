# %%
import pandas as pd
import numpy as np

# %%
flats = pd.read_csv('/content/flats.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
flats.sample(5)
# Out:
#                          property_name  \
# 2593               2 BHK Flat in Sohna
# 940    3 BHK Flat in Sector 83 Gurgaon
# 2491  3 BHK Flat in Sector 113 Gurgaon
# 1979   3 BHK Flat in Sector 86 Gurgaon
# 2426   3 BHK Flat in Sector 76 Gurgaon
#
#                                                    link  \
# 2593  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 940   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2491  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1979  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2426  https://www.99acres.com/3-bhk-bedroom-apartmen...
#
#                          society       price             area  \
# 2593  Signature Global Park4.0 ★      68 Lac   ₹ 8,252/sq.ft.
# 940       Vatika Gurgaon 213.7 ★  1.12 Crore   ₹ 6,455/sq.ft.
# 2491   Tata Gurgaon Gateway3.8 ★  3.21 Crore  ₹ 11,825/sq.ft.
# 1979            Ansal Heights 86  1.25 Crore   ₹ 7,396/sq.ft.
# 2426        Whiteland Blissville  1.92 Crore  ₹ 11,500/sq.ft.
#
# ...

# %%
flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   object
#  1   link             3028 non-null   object
#  2   society          3027 non-null   object
#  3   price            3008 non-null   object
#  4   area             3015 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
flats.duplicated().sum()
# Out:
# 0

# %%
flats.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64

# %%
#droping link and Property_id columns
flats.drop(columns = ['link','property_id'],inplace=True)

# %%
flats.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
flats.rename(columns={'area':'price_per_sqft'},inplace=True)
flats.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
#society column has unnecessary rating
flats['society'].value_counts().head()
# Out:
# SS The Leaf3.8 ★                             73
# Tulip Violet4.3 ★                            40
# Shapoorji Pallonji Joyville Gurugram4.0 ★    39
# Signature Global Park4.0 ★                   36
# Shree Vardhman Victoria3.8 ★                 35
# Name: society, dtype: int64

# %%
#remove stars and numbers using regular expression
import re
flats['society'] = flats['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★','', str(name)).strip()).str.lower()

# %%
flats['society'].head()
# Out:
# 0    maa bhagwati residency
# 1              apna enclave
# 2    tulsiani easy in homes
# 3       smart world orchard
# 4          parkwood westend
# Name: society, dtype: object

# %%
flats.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            apna enclave      50 Lac
# 2              2 BHK Flat in Sohna  tulsiani easy in homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
# price is in two formate lac and crore
flats['price'].value_counts()
# Out:
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.5 Crore           59
# 1.2 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 75 Lac              38
# 1.65 Crore          38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 1.45 Crore          31
# 85 Lac              31
# 1.05 Crore          30
# 2.5 Crore           29
# 60 Lac              29
# 40 Lac              29
# 2.1 Crore           26
# 45 Lac              26
# 65 Lac              25
# 35 Lac              23
# 1.85 Crore          23
# 2.35 Crore          23
# 3 Crore             22
# 70 Lac              21
# 2.25 Crore          20
# 55 Lac              20
# 3.5 Crore           19
# ...

# %%
flats = flats[flats['price'] !='Price on Request']

# %%
flats.dropna(subset='price',inplace=True)
# Out:
# <ipython-input-17-e4a82a976c42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flats.dropna(subset='price',inplace=True)

# %%
def treat_price(x):
    if type(x) == float:
        return x
    else:
      if len(x) ==2:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        elif x[1] == 'Crore':
            return round(float(x[0]),2)
      else:
        return x

# %%
flats['price'] = flats['price'].str.split(' ').apply(treat_price)

# %%
flats['price'].shape
# Out:
# (2997,)

# %%
flats['price_per_sqft'].value_counts()
# Out:
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 5,000/sq.ft.      13
# ₹ 6,666/sq.ft.      13
# ₹ 7,500/sq.ft.      12
# ₹ 8,333/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 12,000/sq.ft.      8
# ₹ 7,000/sq.ft.       8
# ₹ 9,000/sq.ft.       7
# ₹ 9,230/sq.ft.       6
# ₹ 11,111/sq.ft.      6
# ₹ 8,928/sq.ft.       6
# ₹ 6,578/sq.ft.       6
# ₹ 5,500/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 4,666/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 8,571/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 7,641/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,142/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,888/sq.ft.       5
# ₹ 7,692/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 5,384/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 6,500/sq.ft.       5
# ₹ 8,043/sq.ft.       4
# ₹ 8,784/sq.ft.       4
# ₹ 15,000/sq.ft.      4
# ₹ 13,750/sq.ft.      4
# ...

# %%
flats[flats['price_per_sqft'].str.contains('area')]
# Out:
#      property_name  society    price price_per_sqft  areaWithType  bedRoom  \
# 286  property_name  society  [price]           area  areaWithType  bedRoom
#
#      bathroom  balcony  additionalRoom  address  floorNum  facing  \
# 286  bathroom  balcony  additionalRoom  address  floorNum  facing
#
#      agePossession  nearbyLocations  description  furnishDetails  features  \
# 286  agePossession  nearbyLocations  description  furnishDetails  features
#
#      rating
# 286  rating

# %%
flats.drop([286],inplace=True)

# %%
flats['price_per_sqft'] = flats['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
flats['price_per_sqft'].value_counts().sample(10)
# Out:
# 10022.0    1
# 9912.0     1
# 6926.0     1
# 8450.0     3
# 14420.0    1
# 6811.0     2
# 9011.0     3
# 11559.0    1
# 8043.0     4
# 22388.0    1
# Name: price_per_sqft, dtype: int64

# %%
flats['bedRoom'].value_counts()
# Out:
# 3 Bedrooms    1437
# 2 Bedrooms     943
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: bedRoom, dtype: int64

# %%
flats['bedRoom'].isnull().sum()
# Out:
# 0

# %%
flats['bedRoom'] = flats['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
flats.head()
# Out:
#                      property_name                 society price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency  0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.5
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.4
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.7
#
#    price_per_sqft                            areaWithType  bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
flats['balcony'].value_counts()
# Out:
# 3 Balconies     973
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: balcony, dtype: int64

# %%
flats['balcony'] = flats['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
flats['bathroom'].value_counts()
# Out:
# 2 Bathrooms    1043
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# Name: bathroom, dtype: int64

# %%
flats['bathroom'] = flats['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
flats.head()
# Out:
#                      property_name                 society price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency  0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.5
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.4
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.7
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
flats['additionalRoom'].value_counts()
# Out:
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# Study Room,Servant Room,Store Room                 7
# ...

# %%
flats['additionalRoom'].isnull().sum()
# Out:
# 1304

# %%
flats['additionalRoom'].fillna('not available',inplace=True)

# %%
flats['additionalRoom'] = flats['additionalRoom'].str.lower()

# %%
flats.head()
# Out:
#                      property_name                 society price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency  0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.5
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.4
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard  1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.7
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#   balcony additionalRoom                              address  \
# ...

# %%
flats['floorNum'].value_counts().sample(20)
# Out:
# 16th   of 34 Floors     2
# 19th   of 22 Floors     1
# 24th   of 30 Floors     2
# 5th   of 27 Floors      1
# 18th   of 19 Floors     9
# 2nd   of 4 Floors      74
# 3rd   of 5 Floors      10
# 15th   of 30 Floors     1
# 4th   of 22 Floors      5
# 1st   of 5 Floors       6
# Ground of 26 Floors     3
# 4th   of 34 Floors      2
# 12nd   of 39 Floors     1
# 8th   of 19 Floors     24
# 30th   of 34 Floors     1
# 12nd   of 13 Floors     7
# 18th   of 25 Floors     1
# 14th   of 17 Floors     4
# 1st   of 44 Floors      1
# 7th   of 25 Floors      1
# Name: floorNum, dtype: int64

# %%
#we can find floorNum is address
flats[flats['floorNum'].isnull()]
# Out:
#                                 property_name             society price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  experion heartsong  1.08
# 2767          2 BHK Flat in Sector 78 Gurgaon                 nan   0.6
#
#       price_per_sqft                        areaWithType  bedRoom  bathroom  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)        3         3
# 2767          3692.0  Built Up area: 1625 (150.97 sq.m.)        2         2
#
#      balcony additionalRoom  \
# 181        0  not available
# 2767       0  not available
#
#                                                 address floorNum facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...      NaN    NaN
# 2767       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana      NaN    NaN
#
#            agePossession nearbyLocations  \
# 181   Under Construction             NaN
# 2767  Under Construction             NaN
#
#                                             description furnishDetails  \
# ...

# %%
flats.loc[181,'floorNum'] = '6t of b-3'

# %%
flats.dropna(subset=['floorNum'],inplace=True)

# %%
flats.shape
# Out:
# (2995, 18)

# %%
flats['floorNum'] = flats['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
flats['facing'].value_counts()
# Out:
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
flats['facing'].isnull().sum()
# Out:
# 873

# %%
flats['facing'].fillna('Na',inplace=True)

# %%
flats['price']=flats['price'].astype(float)

# %%
flats.insert(loc=4,column='area',value=round((flats['price']*10000000)/flats['price_per_sqft']))

# %%
flats.insert(loc=1,column='property_type',value='flat')

# %%
flats.sample(10)
# Out:
#                          property_name property_type  \
# 87    3 BHK Flat in Sector 109 Gurgaon          flat
# 2623  2 BHK Flat in Sector 102 Gurgaon          flat
# 685    4 BHK Flat in Sector 85 Gurgaon          flat
# 272    3 BHK Flat in Sector 82 Gurgaon          flat
# 431      3 BHK Flat in Sector-33 Sohna          flat
# 2776        2 BHK Flat in Laxman Vihar          flat
# 963   3 BHK Flat in Sector 108 Gurgaon          flat
# 2289     2 BHK Flat in Sector-33 Sohna          flat
# 2500         4 BHK Flat in DLF Phase 5          flat
# 1719   2 BHK Flat in Sector 86 Gurgaon          flat
#
#                                    society  price  price_per_sqft    area  \
# 87             brisk lumbini terrace homes   1.38          6338.0  2177.0
# 2623  shapoorji pallonji joyville gurugram   1.60         11700.0  1368.0
# 685              orris aster court premier   1.50          5859.0  2560.0
# 272                      mapsko casa bella   1.25          6377.0  1960.0
# ...

# %%
flats.to_csv('flats_cleaned.csv',index=False)
